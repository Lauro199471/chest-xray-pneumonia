# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models # add models to the list
from torchvision.utils import make_grid
import math
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
# %matplotlib inline

# ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
train_transform = transforms.Compose([
        transforms.RandomRotation(10),     
        transforms.RandomHorizontalFlip(),
        transforms.Resize((227,227)),
        transforms.ToTensor(),
    ])

test_transform = transforms.Compose([
        transforms.Resize((227,227)),
        transforms.ToTensor(),
    ])

val_transform = transforms.Compose([
        transforms.Resize((227,227)),
        transforms.ToTensor(),
    ])

# %%
root = '../../chest_xray/'

torch.manual_seed(101)
train_data = datasets.ImageFolder(os.path.join(root, 'train'), transform=train_transform)
test_data = datasets.ImageFolder(os.path.join(root, 'test'), transform=test_transform)
val_data = datasets.ImageFolder(os.path.join(root, 'val'), transform=val_transform)

torch.manual_seed(42)
batch_size = 10
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=len(test_data), shuffle=False)
val_loader = DataLoader(val_data, batch_size=len(val_data), shuffle=False)

train_loader.pin_memory = True
test_loader.pin_memory = True
val_loader.pin_memory = True

class_names = train_data.classes

print(class_names)
print(f'Training images available: {len(train_data)}')
print(f'testing images available:  {len(test_data)}')
print(f'Validation images available:  {len(val_data)}')
# Out:
# ['NORMAL', 'PNEUMONIA']
# Training images available: 5005
# testing images available:  624
# Validation images available:  227

# %%
class AlexNet(nn.Module):

    def __init__(self, num_classes=2):
        super(AlexNet, self).__init__()
#         Create storage attributes for data analysis
        self.train_losses = []
        self.train_correct = []
        self.val_losses = []
        self.val_correct = []
        self.min_loss = 100
        self.epoch = 0
        
#         Create the sequence of feature maps
        self.features = nn.Sequential(
#             Input size 227x227x3
            nn.Conv2d(3, 96, kernel_size=11, stride=4),
#             Data now (227 - 11)/4 + 1 = 55x55x96
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(96, 256, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(256, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(-1, 6*6*256)
        x = self.classifier(x)
        return F.log_softmax(x, 1)

# %%
torch.manual_seed(200)
model = AlexNet().cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
model.eval()
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
import time
torch.manual_seed(321)

start_time = time.time()

epochs = 150

# max_trn_batch = 10
# max_val_batch = 2



for i in range(epochs):
    trn_corr = 0
    tst_corr = 0
    avg_loss = 0
    
    # Run the training batches
    for b, (X_train, y_train) in enumerate(train_loader):
        X_train, y_train = X_train.to(device), y_train.to(device)
        b+=1
        
        # Apply the model
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
        avg_loss += loss
 
        # Tally the number of correct predictions
        predicted = torch.max(y_pred.data, 1)[1]
        batch_corr = (predicted == y_train).sum()
        trn_corr += batch_corr
        
        # Update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print interim results
    avg_loss /= b    
    print(f'epoch: {model.epoch:2}  loss: {avg_loss:10.8f}  \
            accuracy: {trn_corr.item()*100/(batch_size*b):7.3f}%')

    torch.cuda.empty_cache()
    model.train_losses.append(avg_loss)
    model.train_correct.append(trn_corr)

    # Run the valing batches
    with torch.no_grad():
        loss = 0
        for b, (X_val, y_val) in enumerate(val_loader):
            X_val, y_val = X_val.to(device), y_val.to(device)

            # Apply the model
            y_pred = model(X_val)
            loss += criterion(y_pred, y_val)

            # Tally the number of correct predictions
            predicted = torch.max(y_pred.data, 1)[1] 
            tst_corr += (predicted == y_val).sum()

    print(f'Validation set: loss: {loss.item():10.8f}  \
                    accuracy: {tst_corr.item()*100/(len(val_data)):7.3f}%')
    if loss < model.min_loss:
        torch.save(model, f'AlexnetEpoch{model.epoch}.pt')
        model.min_loss = loss
    model.val_losses.append(loss)
    model.val_correct.append(tst_corr)
    model.epoch += 1
    torch.save(model, f'AlexnetCurrent.pt')
    torch.cuda.empty_cache()

torch.save(model, f'AlexnetFinal.pt')
print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:  0  loss: 0.42370579              accuracy:  81.317%
# Validation set: loss: 0.22606394                      accuracy:  88.546%
# epoch:  1  loss: 0.18848349              accuracy:  92.675%
# Validation set: loss: 0.19510944                      accuracy:  91.630%
# epoch:  2  loss: 0.12801388              accuracy:  95.309%
# Validation set: loss: 0.17956688                      accuracy:  92.070%
# epoch:  3  loss: 0.11599140              accuracy:  95.689%
# Validation set: loss: 0.17171650                      accuracy:  92.511%
# epoch:  4  loss: 0.10520922              accuracy:  95.908%
# Validation set: loss: 0.10912942                      accuracy:  96.035%
# epoch:  5  loss: 0.08996583              accuracy:  96.707%
# Validation set: loss: 0.19372743                      accuracy:  93.833%
# epoch:  6  loss: 0.08745484              accuracy:  96.427%
# Validation set: loss: 0.09656522                      accuracy:  96.035%
# epoch:  7  loss: 0.08335678              accuracy:  96.627%
# Validation set: loss: 0.10602457                      accuracy:  94.273%
# epoch:  8  loss: 0.08226670              accuracy:  96.826%
# Validation set: loss: 0.10309969                      accuracy:  95.595%
# epoch:  9  loss: 0.08052576              accuracy:  97.186%
# Validation set: loss: 0.09957151                      accuracy:  96.476%
# epoch: 10  loss: 0.08381488              accuracy:  96.707%
# Validation set: loss: 0.10816611                      accuracy:  95.154%
# epoch: 11  loss: 0.07102490              accuracy:  97.305%
# Validation set: loss: 0.07916698                      accuracy:  97.357%
# epoch: 12  loss: 0.07796615              accuracy:  97.066%
# Validation set: loss: 0.15011981                      accuracy:  94.714%
# epoch: 13  loss: 0.06782783              accuracy:  97.545%
# Validation set: loss: 0.11168779                      accuracy:  95.154%
# epoch: 14  loss: 0.06518726              accuracy:  97.645%
# Validation set: loss: 0.10537291                      accuracy:  95.595%
# epoch: 15  loss: 0.06094224              accuracy:  97.665%
# Validation set: loss: 0.07368923                      accuracy:  96.916%
# epoch: 16  loss: 0.06478208              accuracy:  97.585%
# Validation set: loss: 0.07773117                      accuracy:  96.035%
# epoch: 17  loss: 0.05678505              accuracy:  97.645%
# Validation set: loss: 0.05738582                      accuracy:  96.916%
# epoch: 18  loss: 0.05315185              accuracy:  97.705%
# Validation set: loss: 0.11925575                      accuracy:  93.392%
# epoch: 19  loss: 0.05563185              accuracy:  97.844%
# Validation set: loss: 0.04843236                      accuracy:  98.678%
# epoch: 20  loss: 0.05447831              accuracy:  98.004%
# Validation set: loss: 0.08522481                      accuracy:  95.595%
# epoch: 21  loss: 0.05406410              accuracy:  98.024%
# Validation set: loss: 0.08035047                      accuracy:  96.035%
# epoch: 22  loss: 0.04657700              accuracy:  98.204%
# Validation set: loss: 0.06527308                      accuracy:  96.476%
# epoch: 23  loss: 0.05189307              accuracy:  97.984%
# Validation set: loss: 0.05761626                      accuracy:  96.916%
# epoch: 24  loss: 0.04609001              accuracy:  98.383%
# Validation set: loss: 0.07471784                      accuracy:  96.916%
# epoch: 25  loss: 0.04471332              accuracy:  98.403%
# Validation set: loss: 0.09961462                      accuracy:  95.154%
# epoch: 26  loss: 0.04711401              accuracy:  98.323%
# Validation set: loss: 0.09838992                      accuracy:  95.595%
# epoch: 27  loss: 0.05120413              accuracy:  98.283%
# Validation set: loss: 0.06646681                      accuracy:  97.357%
# epoch: 28  loss: 0.04150100              accuracy:  98.423%
# Validation set: loss: 0.11439152                      accuracy:  96.035%
# epoch: 29  loss: 0.04588922              accuracy:  98.283%
# Validation set: loss: 0.13755649                      accuracy:  96.035%
# epoch: 30  loss: 0.03886348              accuracy:  98.543%
# Validation set: loss: 0.09569847                      accuracy:  95.595%
# epoch: 31  loss: 0.04403241              accuracy:  98.164%
# Validation set: loss: 0.07004469                      accuracy:  97.357%
# epoch: 32  loss: 0.03846755              accuracy:  98.423%
# Validation set: loss: 0.10967787                      accuracy:  96.035%
# epoch: 33  loss: 0.03945612              accuracy:  98.503%
# Validation set: loss: 0.06866624                      accuracy:  96.476%
# epoch: 34  loss: 0.03427773              accuracy:  98.643%
# Validation set: loss: 0.06523097                      accuracy:  96.035%
# epoch: 35  loss: 0.03425990              accuracy:  98.523%
# Validation set: loss: 0.06454705                      accuracy:  97.357%
# epoch: 36  loss: 0.03373252              accuracy:  98.683%
# Validation set: loss: 0.05280729                      accuracy:  98.238%
# epoch: 37  loss: 0.03006667              accuracy:  98.902%
# Validation set: loss: 0.07890449                      accuracy:  97.797%
# epoch: 38  loss: 0.03500213              accuracy:  98.643%
# Validation set: loss: 0.12023360                      accuracy:  95.595%
# epoch: 39  loss: 0.03520118              accuracy:  98.623%
# Validation set: loss: 0.04820698                      accuracy:  96.916%
# epoch: 40  loss: 0.03110034              accuracy:  98.743%
# Validation set: loss: 0.04035043                      accuracy:  97.797%
# epoch: 41  loss: 0.03320545              accuracy:  98.703%
# Validation set: loss: 0.05297572                      accuracy:  97.797%
# epoch: 42  loss: 0.03021087              accuracy:  98.862%
# Validation set: loss: 0.07134686                      accuracy:  97.357%
# epoch: 43  loss: 0.02888602              accuracy:  98.862%
# Validation set: loss: 0.04215784                      accuracy:  98.678%
# epoch: 44  loss: 0.03146140              accuracy:  98.643%
# Validation set: loss: 0.04928940                      accuracy:  98.238%
# epoch: 45  loss: 0.02940386              accuracy:  98.822%
# Validation set: loss: 0.04144694                      accuracy:  98.678%
# epoch: 46  loss: 0.03321976              accuracy:  98.703%
# Validation set: loss: 0.04769232                      accuracy:  97.357%
# epoch: 47  loss: 0.02673817              accuracy:  98.842%
# Validation set: loss: 0.06020771                      accuracy:  97.797%
# epoch: 48  loss: 0.02731654              accuracy:  98.982%
# Validation set: loss: 0.09460737                      accuracy:  97.357%
# epoch: 49  loss: 0.02904714              accuracy:  98.802%
# Validation set: loss: 0.07603044                      accuracy:  97.357%
# epoch: 50  loss: 0.02111125              accuracy:  99.182%
# Validation set: loss: 0.08761001                      accuracy:  96.035%
# epoch: 51  loss: 0.03122351              accuracy:  98.882%
# Validation set: loss: 0.09498394                      accuracy:  97.357%
# epoch: 52  loss: 0.02668989              accuracy:  99.022%
# Validation set: loss: 0.07979435                      accuracy:  96.916%
# epoch: 53  loss: 0.02463351              accuracy:  98.942%
# Validation set: loss: 0.07018307                      accuracy:  97.357%
# epoch: 54  loss: 0.02336457              accuracy:  99.042%
# Validation set: loss: 0.06877217                      accuracy:  96.476%
# epoch: 55  loss: 0.03141437              accuracy:  98.762%
# Validation set: loss: 0.05742183                      accuracy:  97.357%
# epoch: 56  loss: 0.02262041              accuracy:  99.022%
# Validation set: loss: 0.04955462                      accuracy:  98.238%
# epoch: 57  loss: 0.02376492              accuracy:  99.082%
# Validation set: loss: 0.10837214                      accuracy:  97.797%
# epoch: 58  loss: 0.02802294              accuracy:  98.882%
# Validation set: loss: 0.06820668                      accuracy:  96.916%
# epoch: 59  loss: 0.01941676              accuracy:  99.281%
# Validation set: loss: 0.11415653                      accuracy:  97.357%
# epoch: 60  loss: 0.02344686              accuracy:  99.122%
# Validation set: loss: 0.07673072                      accuracy:  97.357%
# epoch: 61  loss: 0.02017763              accuracy:  99.202%
# Validation set: loss: 0.07364018                      accuracy:  96.476%
# epoch: 62  loss: 0.01920733              accuracy:  99.162%
# Validation set: loss: 0.09936021                      accuracy:  95.154%
# epoch: 63  loss: 0.01995727              accuracy:  99.142%
# Validation set: loss: 0.06684501                      accuracy:  97.357%
# epoch: 64  loss: 0.02394227              accuracy:  99.222%
# Validation set: loss: 0.07562889                      accuracy:  96.476%
# epoch: 65  loss: 0.02305402              accuracy:  99.242%
# Validation set: loss: 0.13357313                      accuracy:  96.916%
# epoch: 66  loss: 0.02436379              accuracy:  99.062%
# Validation set: loss: 0.06224753                      accuracy:  97.797%
# epoch: 67  loss: 0.02111391              accuracy:  99.102%
# Validation set: loss: 0.14913167                      accuracy:  96.916%
# epoch: 68  loss: 0.01681473              accuracy:  99.142%
# Validation set: loss: 0.08044346                      accuracy:  97.357%
# epoch: 69  loss: 0.01670309              accuracy:  99.381%
# Validation set: loss: 0.05548213                      accuracy:  98.238%
# epoch: 70  loss: 0.02486997              accuracy:  99.002%
# Validation set: loss: 0.06730907                      accuracy:  96.916%
# epoch: 71  loss: 0.01936569              accuracy:  99.222%
# Validation set: loss: 0.04352179                      accuracy:  97.797%
# epoch: 72  loss: 0.01997763              accuracy:  99.242%
# Validation set: loss: 0.08179329                      accuracy:  97.357%
# epoch: 73  loss: 0.01890701              accuracy:  99.301%
# Validation set: loss: 0.05286141                      accuracy:  97.357%
# epoch: 74  loss: 0.01841068              accuracy:  99.381%
# Validation set: loss: 0.05635768                      accuracy:  97.357%
# epoch: 75  loss: 0.01634129              accuracy:  99.361%
# Validation set: loss: 0.06600567                      accuracy:  97.357%
# epoch: 76  loss: 0.01945142              accuracy:  99.242%
# Validation set: loss: 0.08189480                      accuracy:  96.916%
# epoch: 77  loss: 0.01079913              accuracy:  99.461%
# Validation set: loss: 0.06038094                      accuracy:  97.797%
# epoch: 78  loss: 0.01760553              accuracy:  99.242%
# Validation set: loss: 0.08202198                      accuracy:  96.916%
# epoch: 79  loss: 0.02001137              accuracy:  99.261%
# Validation set: loss: 0.10568911                      accuracy:  96.476%
# epoch: 80  loss: 0.01599073              accuracy:  99.281%
# Validation set: loss: 0.06885792                      accuracy:  96.476%
# epoch: 81  loss: 0.01985139              accuracy:  99.222%
# Validation set: loss: 0.08982439                      accuracy:  96.916%
# epoch: 82  loss: 0.01689132              accuracy:  99.321%
# Validation set: loss: 0.06194206                      accuracy:  97.357%
# epoch: 83  loss: 0.01247927              accuracy:  99.461%
# Validation set: loss: 0.07367028                      accuracy:  96.916%
# epoch: 84  loss: 0.01714083              accuracy:  99.261%
# Validation set: loss: 0.06508612                      accuracy:  96.916%
# epoch: 85  loss: 0.01431958              accuracy:  99.521%
# Validation set: loss: 0.11828653                      accuracy:  96.916%
# epoch: 86  loss: 0.01849126              accuracy:  99.222%
# Validation set: loss: 0.10111541                      accuracy:  96.476%
# epoch: 87  loss: 0.02225416              accuracy:  99.202%
# Validation set: loss: 0.04665977                      accuracy:  98.238%
# epoch: 88  loss: 0.01072416              accuracy:  99.521%
# Validation set: loss: 0.04527259                      accuracy:  97.797%
# epoch: 89  loss: 0.01353023              accuracy:  99.521%
# Validation set: loss: 0.07452469                      accuracy:  96.476%
# epoch: 90  loss: 0.01228224              accuracy:  99.501%
# Validation set: loss: 0.08765604                      accuracy:  96.476%
# epoch: 91  loss: 0.01537954              accuracy:  99.421%
# Validation set: loss: 0.09429709                      accuracy:  95.595%
# epoch: 92  loss: 0.02050442              accuracy:  99.182%
# Validation set: loss: 0.21301679                      accuracy:  94.273%
# epoch: 93  loss: 0.02268399              accuracy:  99.202%
# Validation set: loss: 0.07952951                      accuracy:  97.357%
# epoch: 94  loss: 0.00926241              accuracy:  99.601%
# Validation set: loss: 0.24177156                      accuracy:  94.714%
# epoch: 95  loss: 0.01496445              accuracy:  99.401%
# Validation set: loss: 0.09298047                      accuracy:  96.916%
# epoch: 96  loss: 0.01490437              accuracy:  99.441%
# Validation set: loss: 0.10592364                      accuracy:  95.595%
# epoch: 97  loss: 0.01589199              accuracy:  99.421%
# Validation set: loss: 0.08813387                      accuracy:  96.916%
# epoch: 98  loss: 0.00785097              accuracy:  99.661%
# Validation set: loss: 0.05562755                      accuracy:  97.797%
# epoch: 99  loss: 0.01422037              accuracy:  99.441%
# Validation set: loss: 0.17845218                      accuracy:  96.476%
# epoch: 100  loss: 0.02388396              accuracy:  99.261%
# Validation set: loss: 0.20725155                      accuracy:  96.035%
# epoch: 101  loss: 0.01498614              accuracy:  99.341%
# Validation set: loss: 0.08470674                      accuracy:  96.916%
# epoch: 102  loss: 0.01046415              accuracy:  99.481%
# Validation set: loss: 0.31145391                      accuracy:  93.392%
# epoch: 103  loss: 0.02014760              accuracy:  99.162%
# Validation set: loss: 0.06977566                      accuracy:  97.797%
# epoch: 104  loss: 0.01648877              accuracy:  99.321%
# Validation set: loss: 0.05373910                      accuracy:  97.357%
# epoch: 105  loss: 0.01274156              accuracy:  99.481%
# Validation set: loss: 0.06968328                      accuracy:  98.238%
# epoch: 106  loss: 0.02043423              accuracy:  99.281%
# Validation set: loss: 0.05805429                      accuracy:  98.238%
# epoch: 107  loss: 0.00965451              accuracy:  99.541%
# Validation set: loss: 0.13804886                      accuracy:  96.916%
# epoch: 108  loss: 0.01368742              accuracy:  99.341%
# Validation set: loss: 0.07864880                      accuracy:  96.916%
# epoch: 109  loss: 0.01217050              accuracy:  99.501%
# Validation set: loss: 0.07540353                      accuracy:  96.476%
# epoch: 110  loss: 0.01014473              accuracy:  99.521%
# Validation set: loss: 0.09288308                      accuracy:  97.357%
# epoch: 111  loss: 0.00931747              accuracy:  99.581%
# Validation set: loss: 0.14693581                      accuracy:  96.476%
# epoch: 112  loss: 0.01212440              accuracy:  99.441%
# Validation set: loss: 0.08098141                      accuracy:  96.476%
# epoch: 113  loss: 0.01020146              accuracy:  99.641%
# Validation set: loss: 0.13660255                      accuracy:  97.357%
# epoch: 114  loss: 0.01288466              accuracy:  99.501%
# Validation set: loss: 0.10570145                      accuracy:  97.357%
# epoch: 115  loss: 0.01400968              accuracy:  99.501%
# Validation set: loss: 0.18117027                      accuracy:  95.154%
# epoch: 116  loss: 0.01358621              accuracy:  99.361%
# Validation set: loss: 0.10855617                      accuracy:  95.154%
# epoch: 117  loss: 0.01145290              accuracy:  99.541%
# Validation set: loss: 0.09816485                      accuracy:  96.035%
# epoch: 118  loss: 0.01064394              accuracy:  99.581%
# Validation set: loss: 0.14255178                      accuracy:  95.595%
# epoch: 119  loss: 0.01574692              accuracy:  99.321%
# Validation set: loss: 0.12846912                      accuracy:  96.035%
# epoch: 120  loss: 0.01429967              accuracy:  99.301%
# Validation set: loss: 0.12977077                      accuracy:  96.916%
# epoch: 121  loss: 0.00823644              accuracy:  99.521%
# Validation set: loss: 0.13863073                      accuracy:  96.035%
# epoch: 122  loss: 0.01812336              accuracy:  99.301%
# Validation set: loss: 0.07733701                      accuracy:  96.916%
# epoch: 123  loss: 0.01736505              accuracy:  99.301%
# Validation set: loss: 0.09723526                      accuracy:  97.357%
# epoch: 124  loss: 0.01157916              accuracy:  99.501%
# Validation set: loss: 0.08337624                      accuracy:  96.476%
# epoch: 125  loss: 0.00958845              accuracy:  99.521%
# Validation set: loss: 0.10760048                      accuracy:  96.035%
# epoch: 126  loss: 0.00792735              accuracy:  99.661%
# Validation set: loss: 0.24398646                      accuracy:  95.154%
# epoch: 127  loss: 0.01310585              accuracy:  99.421%
# Validation set: loss: 0.09629947                      accuracy:  96.916%
# epoch: 128  loss: 0.00376253              accuracy:  99.780%
# Validation set: loss: 0.20910238                      accuracy:  96.476%
# epoch: 129  loss: 0.00984855              accuracy:  99.521%
# Validation set: loss: 0.04327030                      accuracy:  98.238%
# epoch: 130  loss: 0.01725423              accuracy:  99.242%
# Validation set: loss: 0.13563424                      accuracy:  96.476%
# epoch: 131  loss: 0.00776572              accuracy:  99.581%
# Validation set: loss: 0.08291940                      accuracy:  97.797%
# epoch: 132  loss: 0.01216736              accuracy:  99.461%
# Validation set: loss: 0.09679953                      accuracy:  96.916%
# epoch: 133  loss: 0.02142181              accuracy:  99.361%
# Validation set: loss: 0.13627477                      accuracy:  96.035%
# epoch: 134  loss: 0.00880669              accuracy:  99.701%
# Validation set: loss: 0.13895868                      accuracy:  96.476%
# epoch: 135  loss: 0.00990509              accuracy:  99.421%
# Validation set: loss: 0.09244390                      accuracy:  97.797%
# epoch: 136  loss: 0.00479680              accuracy:  99.760%
# Validation set: loss: 0.27663761                      accuracy:  96.476%
# epoch: 137  loss: 0.05245685              accuracy:  98.922%
# Validation set: loss: 0.07954187                      accuracy:  96.035%
# epoch: 138  loss: 0.01840413              accuracy:  99.182%
# Validation set: loss: 0.05834932                      accuracy:  98.238%
# epoch: 139  loss: 0.00898411              accuracy:  99.561%
# Validation set: loss: 0.04903338                      accuracy:  98.238%
# epoch: 140  loss: 0.00794416              accuracy:  99.561%
# Validation set: loss: 0.15149237                      accuracy:  96.916%
# epoch: 141  loss: 0.01142804              accuracy:  99.541%
# Validation set: loss: 0.07967100                      accuracy:  96.916%
# epoch: 142  loss: 0.00623825              accuracy:  99.681%
# Validation set: loss: 0.07934536                      accuracy:  98.238%
# epoch: 143  loss: 0.00679233              accuracy:  99.741%
# Validation set: loss: 0.09028838                      accuracy:  98.238%
# epoch: 144  loss: 0.01096372              accuracy:  99.561%
# Validation set: loss: 0.09540145                      accuracy:  97.797%
# epoch: 145  loss: 0.01106376              accuracy:  99.481%
# Validation set: loss: 0.14513192                      accuracy:  97.357%
# epoch: 146  loss: 0.00932579              accuracy:  99.581%
# Validation set: loss: 0.08296528                      accuracy:  98.238%
# epoch: 147  loss: 0.01021749              accuracy:  99.541%
# Validation set: loss: 0.10637161                      accuracy:  96.916%
# epoch: 148  loss: 0.01286800              accuracy:  99.521%
# Validation set: loss: 0.27421343                      accuracy:  96.476%
# epoch: 149  loss: 0.00686198              accuracy:  99.681%
# Validation set: loss: 0.07637778                      accuracy:  96.916%
#
# Duration: 26015 seconds

# %%
plt.plot(model.train_losses, label='training loss')
plt.plot(model.val_losses, label='validation loss')
plt.title('Loss at the end of each epoch')
plt.legend();
plt.savefig("AlexnetLoss.png")

# %%
plt.plot([t.item()*100/len(train_data) for t in model.train_correct], label='training accuracy')
plt.plot([t.item()*100/len(val_data) for t in model.val_correct], label='validation accuracy')
plt.title('Accuracy at the end of each epoch')
plt.legend();
plt.savefig("AlexnetAcc.png")

# %%
with torch.no_grad():
    tst_corr = 0
    for b, (X_test, y_test) in enumerate(test_loader):
        X_test, y_test = X_test.to(device), y_test.to(device)
        y_pred = model(X_test)
        predicted = torch.max(y_pred.data, 1)[1] 
        tst_corr += (predicted == y_test).sum()
print(tst_corr.item()/624*100)
# Out:
# 80.76923076923077

# %%
model2 = torch.load('AlexnetEpoch40.pt')
# model2= model
# model2.load_state_dict(torch.load('AlexnetEpoch11.pt'))
model2.eval()
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
with torch.no_grad():
    correct = 0
    for X_test, y_test in test_loader:
        X_test, y_test = X_test.to(device), y_test.to(device)
        y_val = model2(X_test)
        predicted = torch.max(y_val,1)[1]
        if correct == 0:
            test_vals = y_test
            pred_vals = predicted
        else:
            test_vals = torch.cat((test_vals, y_test))
            pred_vals = torch.cat((pred_vals, predicted))
        correct += (predicted == y_test).sum()

print(correct.item()/len(test_data)*100)
arr = confusion_matrix(test_vals.view(-1).cpu(), pred_vals.view(-1).cpu())
df_cm = pd.DataFrame(arr, class_names, class_names)
plt.figure(figsize = (9,6))
sn.heatmap(df_cm, annot=True, fmt="d", cmap='icefire')
plt.xlabel("prediction")
plt.ylabel("label (ground truth)")
plt.show();
plt.savefig("AlexnetHeatMap.png")
# Out:
# 80.60897435897436

# %%
tn, fp, fn, tp = arr.ravel()
precision = tp/(tp+fp)
recall = tp/(tp+fn)

print("Recall of the model is {:.4f}".format(recall))
print("Precision of the model is {:.4f}".format(precision))
# Out:
# Recall of the model is 0.9974
# Precision of the model is 0.7642
