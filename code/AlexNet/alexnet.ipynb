# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models # add models to the list
from torchvision.utils import make_grid
import math
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
# %matplotlib inline

# ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
train_transform = transforms.Compose([
        transforms.RandomRotation(10),     
        transforms.RandomHorizontalFlip(),
        transforms.Resize((227,227)),
        transforms.ToTensor(),
    ])

test_transform = transforms.Compose([
        transforms.Resize((227,227)),
        transforms.ToTensor(),
    ])

val_transform = transforms.Compose([
        transforms.Resize((227,227)),
        transforms.ToTensor(),
    ])

# %%
root = '../chest_xray/'

torch.manual_seed(101)
train_data = datasets.ImageFolder(os.path.join(root, 'train'), transform=train_transform)
test_data = datasets.ImageFolder(os.path.join(root, 'test'), transform=test_transform)
val_data = datasets.ImageFolder(os.path.join(root, 'val'), transform=val_transform)

torch.manual_seed(42)
batch_size = 10
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=len(test_data), shuffle=False)
val_loader = DataLoader(val_data, batch_size=len(val_data), shuffle=False)

train_loader.pin_memory = True
test_loader.pin_memory = True
val_loader.pin_memory = True

class_names = train_data.classes

print(class_names)
print(f'Training images available: {len(train_data)}')
print(f'testing images available:  {len(test_data)}')
print(f'Validation images available:  {len(val_data)}')
# Out:
# ['NORMAL', 'PNEUMONIA']
# Training images available: 5005
# testing images available:  624
# Validation images available:  227

# %%
class AlexNet(nn.Module):

    def __init__(self, num_classes=2):
        super(AlexNet, self).__init__()
        self.train_losses = []
        self.train_correct = []
        self.val_losses = []
        self.val_correct = []
        self.min_loss = 100
        self.epoch = 0
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
torch.manual_seed(200)
model = AlexNet().cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
model.eval()
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
import time
torch.manual_seed(321)

start_time = time.time()

epochs = 150

# max_trn_batch = 10
# max_val_batch = 2



for i in range(epochs):
    trn_corr = 0
    tst_corr = 0
    
    # Run the training batches
    for b, (X_train, y_train) in enumerate(train_loader):
        X_train, y_train = X_train.to(device), y_train.to(device)
        b+=1
        
        # Apply the model
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
 
        # Tally the number of correct predictions
        predicted = torch.max(y_pred.data, 1)[1]
        batch_corr = (predicted == y_train).sum()
        trn_corr += batch_corr
        
        # Update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print interim results
        if b % ((len(train_data)-len(train_data)%10)/batch_size) == 0 or b == (int(len(train_data)/batch_size)):
            print(f'epoch: {model.epoch:2}  batch: {b:4} [{batch_size*b:6}/{len(train_data)}]  loss: {loss.item():10.8f}  \
                    accuracy: {trn_corr.item()*100/(batch_size*b):7.3f}%')

    torch.cuda.empty_cache()
    model.train_losses.append(loss)
    model.train_correct.append(trn_corr)

    # Run the valing batches
    with torch.no_grad():
        loss = 0
        for b, (X_val, y_val) in enumerate(val_loader):
            X_val, y_val = X_val.to(device), y_val.to(device)

            # Apply the model
            y_pred = model(X_val)
            loss += criterion(y_pred, y_val)

            # Tally the number of correct predictions
            predicted = torch.max(y_pred.data, 1)[1] 
            tst_corr += (predicted == y_val).sum()

    print(f'Validation set: loss: {loss.item():10.8f}  \
                    accuracy: {tst_corr.item()*100/(len(val_data)):7.3f}%')
    if loss < model.min_loss:
        torch.save(model, f'AlexnetEpoch{model.epoch}.pt')
        model.min_loss = loss
    model.val_losses.append(loss)
    model.val_correct.append(tst_corr)
    model.epoch += 1
    torch.save(model, f'AlexnetCurrent.pt')
    torch.cuda.empty_cache()

torch.save(model, f'AlexnetFinal.pt')
print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch: 50  batch:  500 [  5000/5005]  loss: 0.00941383                      accuracy:  97.440%
# Validation set: loss: 0.13625608                      accuracy:  94.273%
# epoch: 51  batch:  500 [  5000/5005]  loss: 0.04136456                      accuracy:  97.600%
# Validation set: loss: 0.10994878                      accuracy:  95.595%
# epoch: 52  batch:  500 [  5000/5005]  loss: 0.10812958                      accuracy:  97.680%
# Validation set: loss: 0.07583759                      accuracy:  96.916%
# epoch: 53  batch:  500 [  5000/5005]  loss: 0.00547725                      accuracy:  96.380%
# Validation set: loss: 0.11223476                      accuracy:  94.273%
# epoch: 54  batch:  500 [  5000/5005]  loss: 0.01401275                      accuracy:  96.900%
# Validation set: loss: 0.09702544                      accuracy:  96.476%
# epoch: 55  batch:  500 [  5000/5005]  loss: 0.07171488                      accuracy:  97.620%
# Validation set: loss: 0.05125935                      accuracy:  98.238%
# epoch: 56  batch:  500 [  5000/5005]  loss: 0.02363018                      accuracy:  98.040%
# Validation set: loss: 0.09228310                      accuracy:  95.595%
# epoch: 57  batch:  500 [  5000/5005]  loss: 0.05287664                      accuracy:  97.920%
# Validation set: loss: 0.11731180                      accuracy:  95.595%
# epoch: 58  batch:  500 [  5000/5005]  loss: 0.02598622                      accuracy:  98.000%
# Validation set: loss: 0.09278421                      accuracy:  96.035%
# epoch: 59  batch:  500 [  5000/5005]  loss: 0.01427707                      accuracy:  97.840%
# Validation set: loss: 0.07631488                      accuracy:  96.916%
# epoch: 60  batch:  500 [  5000/5005]  loss: 0.00102019                      accuracy:  97.300%
# Validation set: loss: 0.11502692                      accuracy:  95.595%
# epoch: 61  batch:  500 [  5000/5005]  loss: 0.00001569                      accuracy:  96.780%
# Validation set: loss: 0.09840584                      accuracy:  96.035%
# epoch: 62  batch:  500 [  5000/5005]  loss: 0.04066370                      accuracy:  97.420%
# Validation set: loss: 0.09591841                      accuracy:  95.595%
# epoch: 63  batch:  500 [  5000/5005]  loss: 0.00184863                      accuracy:  98.120%
# Validation set: loss: 0.08659569                      accuracy:  96.035%
# epoch: 64  batch:  500 [  5000/5005]  loss: 0.00752391                      accuracy:  98.040%
# Validation set: loss: 0.12934019                      accuracy:  96.476%
# epoch: 65  batch:  500 [  5000/5005]  loss: 0.28162181                      accuracy:  98.120%
# Validation set: loss: 0.08120111                      accuracy:  97.357%
# epoch: 66  batch:  500 [  5000/5005]  loss: 0.01786422                      accuracy:  98.240%
# Validation set: loss: 0.08438246                      accuracy:  96.476%
# epoch: 67  batch:  500 [  5000/5005]  loss: 0.24957117                      accuracy:  97.180%
# Validation set: loss: 0.09648813                      accuracy:  96.476%
# epoch: 68  batch:  500 [  5000/5005]  loss: 0.03325667                      accuracy:  97.440%
# Validation set: loss: 0.08739459                      accuracy:  95.154%
# epoch: 69  batch:  500 [  5000/5005]  loss: 0.22921476                      accuracy:  97.880%
# Validation set: loss: 0.09637083                      accuracy:  96.476%
# epoch: 70  batch:  500 [  5000/5005]  loss: 0.00614251                      accuracy:  98.100%
# Validation set: loss: 0.09208882                      accuracy:  96.476%
# epoch: 71  batch:  500 [  5000/5005]  loss: 0.03088117                      accuracy:  97.960%
# Validation set: loss: 0.12193336                      accuracy:  95.154%
# epoch: 72  batch:  500 [  5000/5005]  loss: 0.00158377                      accuracy:  98.040%
# Validation set: loss: 0.10293498                      accuracy:  94.714%
# epoch: 73  batch:  500 [  5000/5005]  loss: 0.24127622                      accuracy:  97.840%
# Validation set: loss: 0.06314448                      accuracy:  99.119%
# epoch: 74  batch:  500 [  5000/5005]  loss: 0.05882680                      accuracy:  97.780%
# Validation set: loss: 0.11391870                      accuracy:  94.714%
# epoch: 75  batch:  500 [  5000/5005]  loss: 0.05038894                      accuracy:  97.960%
# Validation set: loss: 0.08633298                      accuracy:  95.595%
# epoch: 76  batch:  500 [  5000/5005]  loss: 0.00098670                      accuracy:  98.080%
# Validation set: loss: 0.11180051                      accuracy:  94.714%
# epoch: 77  batch:  500 [  5000/5005]  loss: 0.00080619                      accuracy:  97.660%
# Validation set: loss: 0.08310903                      accuracy:  96.476%
# epoch: 78  batch:  500 [  5000/5005]  loss: 0.00676376                      accuracy:  98.140%
# Validation set: loss: 0.13014583                      accuracy:  96.035%
# epoch: 79  batch:  500 [  5000/5005]  loss: 0.00317104                      accuracy:  98.340%
# Validation set: loss: 0.12651636                      accuracy:  94.714%
# epoch: 80  batch:  500 [  5000/5005]  loss: 0.00471129                      accuracy:  98.200%
# Validation set: loss: 0.07206265                      accuracy:  96.916%
# epoch: 81  batch:  500 [  5000/5005]  loss: 0.00429823                      accuracy:  98.080%
# Validation set: loss: 0.07176212                      accuracy:  97.797%
# epoch: 82  batch:  500 [  5000/5005]  loss: 0.07201222                      accuracy:  97.980%
# Validation set: loss: 0.06867687                      accuracy:  98.238%
# epoch: 83  batch:  500 [  5000/5005]  loss: 0.26076007                      accuracy:  97.980%
# Validation set: loss: 0.10506225                      accuracy:  96.476%
# epoch: 84  batch:  500 [  5000/5005]  loss: 0.00686717                      accuracy:  97.660%
# Validation set: loss: 0.08578134                      accuracy:  96.035%
# epoch: 85  batch:  500 [  5000/5005]  loss: 0.00212696                      accuracy:  98.180%
# Validation set: loss: 0.07057674                      accuracy:  97.357%
# epoch: 86  batch:  500 [  5000/5005]  loss: 0.05206230                      accuracy:  98.300%
# Validation set: loss: 0.08165518                      accuracy:  96.035%
# epoch: 87  batch:  500 [  5000/5005]  loss: 0.11452633                      accuracy:  98.180%
# Validation set: loss: 0.07933415                      accuracy:  98.238%
# epoch: 88  batch:  500 [  5000/5005]  loss: 0.01694225                      accuracy:  98.160%
# Validation set: loss: 0.11363762                      accuracy:  96.916%
# epoch: 89  batch:  500 [  5000/5005]  loss: 0.10642619                      accuracy:  98.200%
# Validation set: loss: 0.14632644                      accuracy:  93.833%
# epoch: 90  batch:  500 [  5000/5005]  loss: 0.00448798                      accuracy:  97.700%
# Validation set: loss: 0.09132851                      accuracy:  96.476%
# epoch: 91  batch:  500 [  5000/5005]  loss: 0.23465236                      accuracy:  97.940%
# Validation set: loss: 0.08729436                      accuracy:  96.916%
# epoch: 92  batch:  500 [  5000/5005]  loss: 0.02576302                      accuracy:  97.920%
# Validation set: loss: 0.11511395                      accuracy:  95.595%
# epoch: 93  batch:  500 [  5000/5005]  loss: 0.02281521                      accuracy:  98.080%
# Validation set: loss: 0.09973232                      accuracy:  94.714%
# epoch: 94  batch:  500 [  5000/5005]  loss: 0.00096228                      accuracy:  98.200%
# Validation set: loss: 0.09070913                      accuracy:  94.714%
# epoch: 95  batch:  500 [  5000/5005]  loss: 0.01491931                      accuracy:  98.160%
# Validation set: loss: 0.09430838                      accuracy:  95.595%
# epoch: 96  batch:  500 [  5000/5005]  loss: 0.06071633                      accuracy:  98.180%
# Validation set: loss: 0.08231889                      accuracy:  96.476%
# epoch: 97  batch:  500 [  5000/5005]  loss: 0.36078927                      accuracy:  97.920%
# Validation set: loss: 0.11518930                      accuracy:  95.154%
# epoch: 98  batch:  500 [  5000/5005]  loss: 0.30135250                      accuracy:  98.200%
# Validation set: loss: 0.08962774                      accuracy:  95.154%
# epoch: 99  batch:  500 [  5000/5005]  loss: 0.00662899                      accuracy:  98.260%
# Validation set: loss: 0.05120590                      accuracy:  96.916%
# epoch: 100  batch:  500 [  5000/5005]  loss: 0.30816165                      accuracy:  97.920%
# Validation set: loss: 0.11275565                      accuracy:  95.154%
# epoch: 101  batch:  500 [  5000/5005]  loss: 0.00709317                      accuracy:  97.860%
# Validation set: loss: 0.08797304                      accuracy:  96.476%
# epoch: 102  batch:  500 [  5000/5005]  loss: 0.00141041                      accuracy:  97.780%
# Validation set: loss: 0.07789815                      accuracy:  96.476%
# epoch: 103  batch:  500 [  5000/5005]  loss: 0.00004137                      accuracy:  98.000%
# Validation set: loss: 0.11794392                      accuracy:  95.154%
# epoch: 104  batch:  500 [  5000/5005]  loss: 0.00000305                      accuracy:  97.980%
# Validation set: loss: 0.10581532                      accuracy:  95.595%
# epoch: 105  batch:  500 [  5000/5005]  loss: 0.01782450                      accuracy:  97.820%
# Validation set: loss: 0.08815747                      accuracy:  96.476%
# epoch: 106  batch:  500 [  5000/5005]  loss: 0.00937588                      accuracy:  97.720%
# Validation set: loss: 0.10851054                      accuracy:  94.714%
# epoch: 107  batch:  500 [  5000/5005]  loss: 0.01851290                      accuracy:  98.240%
# Validation set: loss: 0.13893902                      accuracy:  94.273%
# epoch: 108  batch:  500 [  5000/5005]  loss: 0.01016858                      accuracy:  97.240%
# Validation set: loss: 0.07854688                      accuracy:  96.476%
# epoch: 109  batch:  500 [  5000/5005]  loss: 0.02153761                      accuracy:  97.820%
# Validation set: loss: 0.23189548                      accuracy:  94.273%
# epoch: 110  batch:  500 [  5000/5005]  loss: 0.00047288                      accuracy:  98.080%
# Validation set: loss: 0.11484712                      accuracy:  95.154%
# epoch: 111  batch:  500 [  5000/5005]  loss: 0.00001590                      accuracy:  98.560%
# Validation set: loss: 0.07477905                      accuracy:  97.797%
# epoch: 112  batch:  500 [  5000/5005]  loss: 0.21573770                      accuracy:  98.400%
# Validation set: loss: 0.09379178                      accuracy:  96.476%
# epoch: 113  batch:  500 [  5000/5005]  loss: 0.03757901                      accuracy:  97.640%
# Validation set: loss: 0.07756764                      accuracy:  96.916%
# epoch: 114  batch:  500 [  5000/5005]  loss: 0.11467713                      accuracy:  97.240%
# Validation set: loss: 0.06699228                      accuracy:  97.357%
# epoch: 115  batch:  500 [  5000/5005]  loss: 0.00495625                      accuracy:  97.740%
# Validation set: loss: 0.08107342                      accuracy:  96.476%
# epoch: 116  batch:  500 [  5000/5005]  loss: 0.29283273                      accuracy:  98.340%
# Validation set: loss: 0.06015284                      accuracy:  97.797%
# epoch: 117  batch:  500 [  5000/5005]  loss: 0.01463782                      accuracy:  98.280%
# Validation set: loss: 0.07953645                      accuracy:  96.476%
# epoch: 118  batch:  500 [  5000/5005]  loss: 0.39543432                      accuracy:  98.280%
# Validation set: loss: 0.05327437                      accuracy:  98.238%
# epoch: 119  batch:  500 [  5000/5005]  loss: 0.17762238                      accuracy:  98.200%
# Validation set: loss: 0.08123782                      accuracy:  96.916%
# epoch: 120  batch:  500 [  5000/5005]  loss: 0.02673097                      accuracy:  97.740%
# Validation set: loss: 0.10121889                      accuracy:  96.035%
# epoch: 121  batch:  500 [  5000/5005]  loss: 0.00519183                      accuracy:  98.440%
# Validation set: loss: 0.09494536                      accuracy:  96.476%
# epoch: 122  batch:  500 [  5000/5005]  loss: 0.00554196                      accuracy:  98.320%
# Validation set: loss: 0.11099518                      accuracy:  96.916%
# epoch: 123  batch:  500 [  5000/5005]  loss: 0.22523239                      accuracy:  98.040%
# Validation set: loss: 0.09373371                      accuracy:  95.595%
# epoch: 124  batch:  500 [  5000/5005]  loss: 0.00403640                      accuracy:  98.440%
# Validation set: loss: 0.09629356                      accuracy:  96.035%
# epoch: 125  batch:  500 [  5000/5005]  loss: 0.01792705                      accuracy:  98.280%
# Validation set: loss: 0.14206323                      accuracy:  94.714%
# epoch: 126  batch:  500 [  5000/5005]  loss: 0.00876458                      accuracy:  96.640%
# Validation set: loss: 0.09584711                      accuracy:  97.797%
# epoch: 127  batch:  500 [  5000/5005]  loss: 0.01712651                      accuracy:  97.840%
# Validation set: loss: 0.07801088                      accuracy:  97.797%
# epoch: 128  batch:  500 [  5000/5005]  loss: 0.00466087                      accuracy:  98.100%
# Validation set: loss: 0.07399744                      accuracy:  97.357%
# epoch: 129  batch:  500 [  5000/5005]  loss: 0.37567252                      accuracy:  98.440%
# Validation set: loss: 0.12193740                      accuracy:  96.035%
# epoch: 130  batch:  500 [  5000/5005]  loss: 0.00059433                      accuracy:  98.360%
# Validation set: loss: 0.09762190                      accuracy:  96.476%
# epoch: 131  batch:  500 [  5000/5005]  loss: 0.41937351                      accuracy:  97.640%
# Validation set: loss: 0.09578602                      accuracy:  96.476%
# epoch: 132  batch:  500 [  5000/5005]  loss: 0.01702797                      accuracy:  98.620%
# Validation set: loss: 0.07669950                      accuracy:  96.916%
# epoch: 133  batch:  500 [  5000/5005]  loss: 0.00448227                      accuracy:  98.760%
# Validation set: loss: 0.11928625                      accuracy:  94.714%
# epoch: 134  batch:  500 [  5000/5005]  loss: 0.02559788                      accuracy:  98.480%
# Validation set: loss: 0.06158775                      accuracy:  98.238%
# epoch: 135  batch:  500 [  5000/5005]  loss: 0.00435815                      accuracy:  98.380%
# Validation set: loss: 0.06294423                      accuracy:  98.238%
# epoch: 136  batch:  500 [  5000/5005]  loss: 0.00543778                      accuracy:  98.240%
# Validation set: loss: 0.08329325                      accuracy:  96.035%
# epoch: 137  batch:  500 [  5000/5005]  loss: 0.02286987                      accuracy:  98.340%
# Validation set: loss: 0.11873148                      accuracy:  96.476%
# epoch: 138  batch:  500 [  5000/5005]  loss: 0.00456672                      accuracy:  98.400%
# Validation set: loss: 0.12363995                      accuracy:  94.714%
# epoch: 139  batch:  500 [  5000/5005]  loss: 0.03983488                      accuracy:  98.680%
# Validation set: loss: 0.11624851                      accuracy:  95.595%
# epoch: 140  batch:  500 [  5000/5005]  loss: 0.00399919                      accuracy:  98.400%
# Validation set: loss: 0.09712963                      accuracy:  96.035%
# epoch: 141  batch:  500 [  5000/5005]  loss: 0.00004206                      accuracy:  98.440%
# Validation set: loss: 0.17327002                      accuracy:  97.357%
# epoch: 142  batch:  500 [  5000/5005]  loss: 0.01415482                      accuracy:  98.320%
# Validation set: loss: 0.08386588                      accuracy:  97.357%
# epoch: 143  batch:  500 [  5000/5005]  loss: 0.00160167                      accuracy:  98.360%
# Validation set: loss: 0.09369471                      accuracy:  96.916%
# epoch: 144  batch:  500 [  5000/5005]  loss: 0.00023761                      accuracy:  98.540%
# Validation set: loss: 0.09059467                      accuracy:  96.476%
# epoch: 145  batch:  500 [  5000/5005]  loss: 0.00811186                      accuracy:  98.620%
# Validation set: loss: 0.06553480                      accuracy:  97.797%
# epoch: 146  batch:  500 [  5000/5005]  loss: 0.02622753                      accuracy:  96.700%
# Validation set: loss: 0.17889833                      accuracy:  92.511%
# epoch: 147  batch:  500 [  5000/5005]  loss: 0.03019569                      accuracy:  97.000%
# Validation set: loss: 0.07533318                      accuracy:  96.035%
# epoch: 148  batch:  500 [  5000/5005]  loss: 0.26225489                      accuracy:  97.520%
# Validation set: loss: 0.07056361                      accuracy:  97.357%
# epoch: 149  batch:  500 [  5000/5005]  loss: 0.01337302                      accuracy:  97.620%
# Validation set: loss: 0.09630656                      accuracy:  95.154%
# epoch: 150  batch:  500 [  5000/5005]  loss: 0.37695229                      accuracy:  98.280%
# Validation set: loss: 0.10442594                      accuracy:  96.035%
# epoch: 151  batch:  500 [  5000/5005]  loss: 0.02595559                      accuracy:  98.360%
# Validation set: loss: 0.07276859                      accuracy:  96.916%
# epoch: 152  batch:  500 [  5000/5005]  loss: 0.00010800                      accuracy:  98.600%
# Validation set: loss: 0.06738590                      accuracy:  98.678%
# epoch: 153  batch:  500 [  5000/5005]  loss: 0.06127129                      accuracy:  97.160%
# Validation set: loss: 0.11264028                      accuracy:  96.916%
# epoch: 154  batch:  500 [  5000/5005]  loss: 0.02329974                      accuracy:  97.600%
# Validation set: loss: 0.10911703                      accuracy:  95.154%
# epoch: 155  batch:  500 [  5000/5005]  loss: 0.12110931                      accuracy:  98.220%
# Validation set: loss: 0.17270429                      accuracy:  93.392%
# epoch: 156  batch:  500 [  5000/5005]  loss: 0.03963493                      accuracy:  97.400%
# Validation set: loss: 0.08494785                      accuracy:  96.476%
# epoch: 157  batch:  500 [  5000/5005]  loss: 0.00644541                      accuracy:  98.080%
# Validation set: loss: 0.09208071                      accuracy:  96.035%
# epoch: 158  batch:  500 [  5000/5005]  loss: 0.00032001                      accuracy:  98.260%
# Validation set: loss: 0.12299818                      accuracy:  94.714%
# epoch: 159  batch:  500 [  5000/5005]  loss: 0.00006347                      accuracy:  98.640%
# Validation set: loss: 0.09136306                      accuracy:  98.238%
# epoch: 160  batch:  500 [  5000/5005]  loss: 0.00272436                      accuracy:  98.440%
# Validation set: loss: 0.07128095                      accuracy:  97.357%
# epoch: 161  batch:  500 [  5000/5005]  loss: 0.00736188                      accuracy:  98.140%
# Validation set: loss: 0.09640659                      accuracy:  96.916%
# epoch: 162  batch:  500 [  5000/5005]  loss: 0.00094392                      accuracy:  98.420%
# Validation set: loss: 0.07308857                      accuracy:  97.357%
# epoch: 163  batch:  500 [  5000/5005]  loss: 0.05253623                      accuracy:  98.280%
# Validation set: loss: 0.11193322                      accuracy:  94.273%
# epoch: 164  batch:  500 [  5000/5005]  loss: 0.00623343                      accuracy:  98.340%
# Validation set: loss: 0.09738228                      accuracy:  95.595%
# epoch: 165  batch:  500 [  5000/5005]  loss: 0.31483021                      accuracy:  98.200%
# Validation set: loss: 0.08179748                      accuracy:  96.476%
# epoch: 166  batch:  500 [  5000/5005]  loss: 0.00121055                      accuracy:  98.520%
# Validation set: loss: 0.07755548                      accuracy:  96.476%
# epoch: 167  batch:  500 [  5000/5005]  loss: 0.00978704                      accuracy:  97.940%
# Validation set: loss: 0.09611228                      accuracy:  97.357%
# epoch: 168  batch:  500 [  5000/5005]  loss: 0.00290613                      accuracy:  97.900%
# Validation set: loss: 0.29719707                      accuracy:  94.273%
# epoch: 169  batch:  500 [  5000/5005]  loss: 0.00306406                      accuracy:  98.300%
# Validation set: loss: 0.08181711                      accuracy:  96.476%
# epoch: 170  batch:  500 [  5000/5005]  loss: 0.00338365                      accuracy:  98.380%
# Validation set: loss: 0.07095701                      accuracy:  96.476%
# epoch: 171  batch:  500 [  5000/5005]  loss: 0.00469100                      accuracy:  98.780%
# Validation set: loss: 0.06930915                      accuracy:  96.916%
# epoch: 172  batch:  500 [  5000/5005]  loss: 0.00259960                      accuracy:  98.660%
# Validation set: loss: 0.08093701                      accuracy:  97.797%
# epoch: 173  batch:  500 [  5000/5005]  loss: 0.00961137                      accuracy:  98.760%
# Validation set: loss: 0.09170996                      accuracy:  97.357%
# epoch: 174  batch:  500 [  5000/5005]  loss: 0.00471298                      accuracy:  97.640%
# Validation set: loss: 0.10323798                      accuracy:  96.035%
# epoch: 175  batch:  500 [  5000/5005]  loss: 0.00525143                      accuracy:  98.320%
# Validation set: loss: 0.11292066                      accuracy:  96.035%
# epoch: 176  batch:  500 [  5000/5005]  loss: 0.00000372                      accuracy:  98.520%
# Validation set: loss: 0.10083350                      accuracy:  96.035%
# epoch: 177  batch:  500 [  5000/5005]  loss: 0.24339171                      accuracy:  98.360%
# Validation set: loss: 0.11603545                      accuracy:  96.035%
# epoch: 178  batch:  500 [  5000/5005]  loss: 0.00203661                      accuracy:  98.640%
# Validation set: loss: 0.08517267                      accuracy:  96.916%
# epoch: 179  batch:  500 [  5000/5005]  loss: 0.02918435                      accuracy:  98.580%
# Validation set: loss: 0.09532054                      accuracy:  96.476%
# epoch: 180  batch:  500 [  5000/5005]  loss: 0.01528029                      accuracy:  98.120%
# Validation set: loss: 0.13562630                      accuracy:  93.833%
# epoch: 181  batch:  500 [  5000/5005]  loss: 0.01029085                      accuracy:  98.500%
# Validation set: loss: 0.08624963                      accuracy:  96.916%
# epoch: 182  batch:  500 [  5000/5005]  loss: 0.02890140                      accuracy:  98.500%
# Validation set: loss: 0.14005287                      accuracy:  94.714%
# epoch: 183  batch:  500 [  5000/5005]  loss: 0.00172572                      accuracy:  98.340%
# Validation set: loss: 0.08120150                      accuracy:  96.916%
# epoch: 184  batch:  500 [  5000/5005]  loss: 0.00151095                      accuracy:  98.660%
# Validation set: loss: 0.08487594                      accuracy:  97.797%
# epoch: 185  batch:  500 [  5000/5005]  loss: 0.02272693                      accuracy:  98.440%
# Validation set: loss: 0.07607527                      accuracy:  96.916%
# epoch: 186  batch:  500 [  5000/5005]  loss: 0.00003059                      accuracy:  98.420%
# Validation set: loss: 0.09563768                      accuracy:  96.476%
# epoch: 187  batch:  500 [  5000/5005]  loss: 0.04526500                      accuracy:  98.600%
# Validation set: loss: 0.08857740                      accuracy:  96.916%
# epoch: 188  batch:  500 [  5000/5005]  loss: 0.00338619                      accuracy:  98.360%
# Validation set: loss: 0.09275167                      accuracy:  96.476%
# epoch: 189  batch:  500 [  5000/5005]  loss: 0.00120008                      accuracy:  98.820%
# Validation set: loss: 0.09277750                      accuracy:  97.357%
# epoch: 190  batch:  500 [  5000/5005]  loss: 0.00410049                      accuracy:  98.400%
# Validation set: loss: 0.14383709                      accuracy:  94.714%
# epoch: 191  batch:  500 [  5000/5005]  loss: 0.37448734                      accuracy:  98.260%
# Validation set: loss: 0.14301516                      accuracy:  93.833%
# epoch: 192  batch:  500 [  5000/5005]  loss: 0.01123875                      accuracy:  98.800%
# Validation set: loss: 0.08208077                      accuracy:  96.476%
# epoch: 193  batch:  500 [  5000/5005]  loss: 0.01335987                      accuracy:  98.560%
# Validation set: loss: 0.07418113                      accuracy:  96.916%
# epoch: 194  batch:  500 [  5000/5005]  loss: 0.00087047                      accuracy:  97.580%
# Validation set: loss: 0.13696648                      accuracy:  94.714%
# epoch: 195  batch:  500 [  5000/5005]  loss: 0.00529847                      accuracy:  97.620%
# Validation set: loss: 0.13682605                      accuracy:  94.273%
# epoch: 196  batch:  500 [  5000/5005]  loss: 0.00801513                      accuracy:  98.560%
# Validation set: loss: 0.10650893                      accuracy:  96.476%
# epoch: 197  batch:  500 [  5000/5005]  loss: 0.00404146                      accuracy:  98.500%
# Validation set: loss: 0.18154928                      accuracy:  95.595%
# epoch: 198  batch:  500 [  5000/5005]  loss: 0.15013734                      accuracy:  98.720%
# Validation set: loss: 0.21313025                      accuracy:  94.273%
# epoch: 199  batch:  500 [  5000/5005]  loss: 0.00874333                      accuracy:  97.380%
# Validation set: loss: 0.14182597                      accuracy:  95.595%
#
# Duration: 14274 seconds

# %%
plt.plot(model.train_losses, label='training loss')
plt.plot(model.val_losses, label='validation loss')
plt.title('Loss at the end of each epoch')
plt.legend();
plt.savefig("AlexnetLoss.png")

# %%
plt.plot([t.item()*100/len(train_data) for t in model.train_correct], label='training accuracy')
plt.plot([t.item()*100/len(val_data) for t in model.val_correct], label='validation accuracy')
plt.title('Accuracy at the end of each epoch')
plt.legend();
plt.savefig("AlexnetAcc.png")

# %%
with torch.no_grad():
    tst_corr = 0
    for b, (X_test, y_test) in enumerate(test_loader):
        X_test, y_test = X_test.to(device), y_test.to(device)
        y_pred = model(X_test)
        predicted = torch.max(y_pred.data, 1)[1] 
        tst_corr += (predicted == y_test).sum()
print(tst_corr.item()/624*100)
# Out:
# 71.7948717948718

# %%
model2 = torch.load('AlexnetEpoch99.pt')
# model2= model
# model2.load_state_dict(torch.load('AlexnetEpoch11.pt'))
model2.eval()
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
test_load_all = DataLoader(test_data, batch_size=len(test_data), shuffle=False)

with torch.no_grad():
    correct = 0
    for X_test, y_test in test_load_all:
        X_test, y_test = X_test.to(device), y_test.to(device)
        y_val = model2(X_test)
        predicted = torch.max(y_val,1)[1]
        correct += (predicted == y_test).sum()

print(tst_corr.item()/624*100)
arr = confusion_matrix(y_test.view(-1).cpu(), predicted.view(-1).cpu())
df_cm = pd.DataFrame(arr, class_names, class_names)
plt.figure(figsize = (9,6))
sn.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("prediction")
plt.ylabel("label (ground truth)")
plt.show();
plt.savefig("AlexnetHeatMap.png")
# Out:
# 71.7948717948718

# %%
tn, fp, fn, tp = arr.ravel()
precision = tp/(tp+fp)
recall = tp/(tp+fn)

print("Recall of the model is {:.2f}".format(recall))
print("Precision of the model is {:.2f}".format(precision))
# Out:
# Recall of the model is 0.99
# Precision of the model is 0.73
